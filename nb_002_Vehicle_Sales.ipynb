# %%
import pandas as pd

# %%
vehicle_sales = pd.read_csv("data/US_Vehicle_Sales.csv",  parse_dates=["DATE"])

# %%
vehicle_sales.dtypes
# Out:
# DATE          datetime64[ns]
# TOTALNSA             float64
# LAUTONSA             float64
# LTRUCKNSA            float64
# HTRUCKSNSA           float64
# dtype: object

# %%
vehicle_sales.plot(x = "DATE")
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
vehicle_sales.set_index('DATE')
vehicle_sales.plot(x = 'DATE')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
plt.plot(vehicle_sales["DATE"], vehicle_sales["TOTALNSA"])

# %%
a = range(1,11)
a
# Out:
# range(1, 11)
