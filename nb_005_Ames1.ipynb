# %%
import geopandas
school_dists = geopandas.read_file('data/geo/ames_school_districts.geojson')
school_dists['color'] = ['#00b2fd', '#A1A600', '#00C377', '#F95DFA', '#FF6C67']

# %%
school_dists.plot(figsize=(15,15), color = school_dists['color'], edgecolor="black")
# Out:
# <AxesSubplot:>

# %%
school_dists
# Out:
#                      district fill_color  \
# 0  Mitchell Elementary School  #bee2efff
# 1   Fellows Elementary School    #bce4bd
# 2    Meeker Elementary School    #f7cb96
# 3    Sawyer Elementary School    #f8cfda
# 4   Edwards Elementary School    #fcf9c6
#
#                                             geometry    color
# 0  MULTIPOLYGON (((-93.58127 42.04173, -93.58127 ...  #00b2fd
# 1  MULTIPOLYGON (((-93.65905 42.05743, -93.65905 ...  #A1A600
# 2  MULTIPOLYGON (((-93.64100 42.04539, -93.64100 ...  #00C377
# 3  MULTIPOLYGON (((-93.64473 42.04238, -93.64473 ...  #F95DFA
# 4  MULTIPOLYGON (((-93.66566 42.03080, -93.66566 ...  #FF6C67
