# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
emps = pd.read_csv("data/ChicagoEmployees.csv")

# %%
emps.head()
# Out:
#                   Name                              Job Titles   Department  \
# 0    AARON,  JEFFERY M                                SERGEANT       POLICE
# 1       AARON,  KARINA  POLICE OFFICER (ASSIGNED AS DETECTIVE)       POLICE
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER         DAIS
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV  WATER MGMNT
# 4    ABARCA,  EMMANUEL                        CONCRETE LABORER   TRANSPORTN
#
#   Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                 F           Salary            NaN       118998.0
# 1                 F           Salary            NaN        97440.0
# 2                 F           Salary            NaN       121272.0
# 3                 F           Salary            NaN       119712.0
# 4                 F           Hourly           40.0            NaN
#
#    Hourly Rate
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4         44.4

# %%
emps.loc[emps['Department'] == "POLICE"]
# Out:
#                        Name                              Job Titles  \
# 0         AARON,  JEFFERY M                                SERGEANT
# 1            AARON,  KARINA  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 5        ABARCA,  FRANCES J                          POLICE OFFICER
# 9          ABBATE,  TERRY M                          POLICE OFFICER
# 11        ABBOTT,  CARMELLA                          POLICE OFFICER
# ...                     ...                                     ...
# 31852  ZYLINSKA,  KATARZYNA                          POLICE OFFICER
# 31853    ZYLINSKA,  KLAUDIA                          POLICE OFFICER
# 31854    ZYMANTAS,  LAURA C                          POLICE OFFICER
# 31855     ZYMANTAS,  MARK E                          POLICE OFFICER
# 31856   ZYRKOWSKI,  CARLO E                          POLICE OFFICER
#
#       Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0         POLICE                 F           Salary            NaN
# ...

# %%
orig_names = list(emps.columns)

# %%
emps = emps.rename(columns={'Annual Salary': 'Salary'})

# %%
emps.head(20)
# Out:
#                         Name                                     Job Titles  \
# 0          AARON,  JEFFERY M                                       SERGEANT
# 1             AARON,  KARINA         POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2        AARON,  KIMBERLEI R                       CHIEF CONTRACT EXPEDITER
# 3        ABAD JR,  VICENTE M                              CIVIL ENGINEER IV
# 4          ABARCA,  EMMANUEL                               CONCRETE LABORER
# 5         ABARCA,  FRANCES J                                 POLICE OFFICER
# 6          ABASCAL,  REECE E                    TRAFFIC CONTROL AIDE-HOURLY
# 7      ABBATACOLA,  ROBERT J                            ELECTRICAL MECHANIC
# 8      ABBATEMARCO,  JAMES J                              FIRE ENGINEER-EMT
# 9           ABBATE,  TERRY M                                 POLICE OFFICER
# 10          ABBOTT,  BETTY L                             FOSTER GRANDPARENT
# ...

# %%
top3 = ['POLICE', 'FIRE', 'STREETS & SAN']
large_depts = emps.loc[(emps['Department'].isin(top3)) & (emps['Salary or Hourly'] == 'Salary')]
large_depts.head()
# Out:
#                     Name                              Job Titles Department  \
# 0      AARON,  JEFFERY M                                SERGEANT     POLICE
# 1         AARON,  KARINA  POLICE OFFICER (ASSIGNED AS DETECTIVE)     POLICE
# 5     ABARCA,  FRANCES J                          POLICE OFFICER     POLICE
# 8  ABBATEMARCO,  JAMES J                       FIRE ENGINEER-EMT       FIRE
# 9       ABBATE,  TERRY M                          POLICE OFFICER     POLICE
#
#   Full or Part-Time Salary or Hourly  Typical Hours    Salary  Hourly Rate
# 0                 F           Salary            NaN  118998.0          NaN
# 1                 F           Salary            NaN   97440.0          NaN
# 5                 F           Salary            NaN   72510.0          NaN
# 8                 F           Salary            NaN  118254.0          NaN
# 9                 F           Salary            NaN   96060.0          NaN

# %%
large_depts.reset_index().drop(columns = ['index'])
# Out:
#                         Name                              Job Titles  \
# 0          AARON,  JEFFERY M                                SERGEANT
# 1             AARON,  KARINA  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2         ABARCA,  FRANCES J                          POLICE OFFICER
# 3      ABBATEMARCO,  JAMES J                       FIRE ENGINEER-EMT
# 4           ABBATE,  TERRY M                          POLICE OFFICER
# ...                      ...                                     ...
# 18140   ZYLINSKA,  KATARZYNA                          POLICE OFFICER
# 18141     ZYLINSKA,  KLAUDIA                          POLICE OFFICER
# 18142     ZYMANTAS,  LAURA C                          POLICE OFFICER
# 18143      ZYMANTAS,  MARK E                          POLICE OFFICER
# 18144    ZYRKOWSKI,  CARLO E                          POLICE OFFICER
#
#       Department Full or Part-Time Salary or Hourly  Typical Hours    Salary  \
# ...

# %%
large_depts.reset_index(drop = True, inplace = True)
large_depts
# Out:
#                         Name                              Job Titles  \
# 0          AARON,  JEFFERY M                                SERGEANT
# 1             AARON,  KARINA  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2         ABARCA,  FRANCES J                          POLICE OFFICER
# 3      ABBATEMARCO,  JAMES J                       FIRE ENGINEER-EMT
# 4           ABBATE,  TERRY M                          POLICE OFFICER
# ...                      ...                                     ...
# 18140   ZYLINSKA,  KATARZYNA                          POLICE OFFICER
# 18141     ZYLINSKA,  KLAUDIA                          POLICE OFFICER
# 18142     ZYMANTAS,  LAURA C                          POLICE OFFICER
# 18143      ZYMANTAS,  MARK E                          POLICE OFFICER
# 18144    ZYRKOWSKI,  CARLO E                          POLICE OFFICER
#
#       Department Full or Part-Time Salary or Hourly  Typical Hours    Salary  \
# ...

# %%
mikes = emps.loc[emps['Name'].str.contains('RUSSELL')]
mikes
# Out:
#                           Name                              Job Titles  \
# 1280        BACIUS,  RUSSELL P                          POLICE OFFICER
# 2338    BLOMSTRAND,  RUSSELL A                         FIREFIGHTER-EMT
# 2871        BRIGGS,  RUSSELL D                          POLICE OFFICER
# 2888       BRISENO,  RUSSELL H                  CERTIFIED MEDICAL ASST
# 7728          EGAN,  RUSSELL A                                SERGEANT
# 7794      ELLIS II,  RUSSELL J                          POLICE OFFICER
# 8142     FAIRCHILD,  RUSSELL H                         FIREFIGHTER-EMT
# 9114        FUJISAWA,  RUSSELL          PROJECT STRATEGY MANAGER - CPD
# 11593      HAWKING,  RUSSELL J                     FLEET SERVICES ASST
# 12939       INNISS,  RUSSELL R                       FIRE ENGINEER-EMT
# 13742      JOHNSON,  RUSSELL L                  PROJECTS ADMINISTRATOR
# 14205       KAPLAN,  RUSSELL A                    CONSTRUCTION LABORER
# ...

# %%
sarahs = emps.loc[emps['Name'].str.contains('MARY')]
sarahs
# Out:
#                        Name                              Job Titles  \
# 22       ABDULLA,  MARYEM E             ASST CORPORATION COUNSEL II
# 401      ALEXANDER,  MARY F                      FOSTER GRANDPARENT
# 552          ALROY,  MARY E                  ADMINISTRATIVE ASST II
# 666       AMANULLAH,  MARYA                          POLICE OFFICER
# 992    ARIAS SUL,  MARYLN C      ADMINISTRATIVE SERVICES OFFICER II
# ...                     ...                                     ...
# 30608      WILKOSZ,  MARY E                          POLICE OFFICER
# 30800     WILLIAMS,  MARY V                         ALDERMANIC AIDE
# 30911   WILLIS IVY,  MARY C  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 31839     ZURAWSKI,  MARY E                          POLICE OFFICER
# 31841        ZUREK,  MARY H       SENIOR PUBLIC INFORMATION OFFICER
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 22                  LAW                 F           Salary            NaN
# ...

# %%
emps.loc[~emps['Department'].isin(top3), 'Department'] = "OTHER"
emps.head(40)
# Out:
#                         Name                                     Job Titles  \
# 0          AARON,  JEFFERY M                                       SERGEANT
# 1             AARON,  KARINA         POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2        AARON,  KIMBERLEI R                       CHIEF CONTRACT EXPEDITER
# 3        ABAD JR,  VICENTE M                              CIVIL ENGINEER IV
# 4          ABARCA,  EMMANUEL                               CONCRETE LABORER
# 5         ABARCA,  FRANCES J                                 POLICE OFFICER
# 6          ABASCAL,  REECE E                    TRAFFIC CONTROL AIDE-HOURLY
# 7      ABBATACOLA,  ROBERT J                            ELECTRICAL MECHANIC
# 8      ABBATEMARCO,  JAMES J                              FIRE ENGINEER-EMT
# 9           ABBATE,  TERRY M                                 POLICE OFFICER
# 10          ABBOTT,  BETTY L                             FOSTER GRANDPARENT
# ...

# %%
import seaborn as sns
sns.boxplot(x= emps['Department'], y = emps['Salary'])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Salary'>

# %%
chi_agg = pd.DataFrame(columns = orig_names)
chi_agg
# Out:
# Empty DataFrame
# Columns: [Name, Job Titles, Department, Full or Part-Time, Salary or Hourly, Typical Hours, Annual Salary, Hourly Rate]
# Index: []

# %%
for temp in pd.read_csv('data/ChicagoEmployees.csv', chunksize = 100):
    dept_counts = temp.groupby(['Department']).count()
    
    print(dept_counts)
# Out:
#                   Name  Job Titles  Full or Part-Time  Salary or Hourly  \
# Department
# AVIATION             6           6                  6                 6
# BUSINESS AFFAIRS     1           1                  1                 1
# DAIS                 3           3                  3                 3
# FAMILY & SUPPORT     2           2                  2                 2
# FINANCE              1           1                  1                 1
# FIRE                16          16                 16                16
# HEALTH               3           3                  3                 3
# HUMAN RESOURCES      1           1                  1                 1
# LAW                  1           1                  1                 1
# OEMC                 3           3                  3                 3
# POLICE              49          49                 49                49
# STREETS & SAN        3           3                  3                 3
# ...
