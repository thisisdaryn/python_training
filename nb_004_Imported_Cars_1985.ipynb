# %%
import pandas as pd

# %%
auto_prices = pd.read_csv('data/ImportedCars1985.csv')

# %%
auto_prices.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
auto_prices.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(auto_prices['city-mpg'], auto_prices['price'], 'ro')

# %% [markdown]
# Pandas has a plot method built-in to the data frame

# %%
auto_prices.plot(kind = 'scatter', x = 'city-mpg', y = 'price')
# Out:
# <AxesSubplot:xlabel='city-mpg', ylabel='price'>

# %%
auto_prices.plot(kind = 'scatter', x = 'curb-weight', y = 'price')
# Out:
# <AxesSubplot:xlabel='curb-weight', ylabel='price'>

# %%
auto_prices.plot(kind = 'scatter', x = 'curb-weight', y = 'city-mpg')
# Out:
# <AxesSubplot:xlabel='curb-weight', ylabel='city-mpg'>

# %%
fig = plt.figure(figsize = (10,6))
ax = fig.gca()
auto_prices.plot(kind = 'scatter', x = 'city-mpg', y = 'price', ax = ax)
ax.set_title('Scatter plot of price vs MPG')
ax.set_xlabel('City MPG')
ax.set_ylabel('Auto Price')
# Out:
# Text(0, 0.5, 'Auto Price')

# %%
counts = auto_prices['make'].value_counts()
counts
# Out:
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              7
# saab              6
# porsche           5
# isuzu             4
# alfa-romero       3
# chevrolet         3
# jaguar            3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
counts.plot.bar()
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize = (10, 10))
ax = fig.gca()
counts.plot.bar(ax = ax)
ax.set_title('Number of auto types by make')
ax.set_xlabel('Make')
ax.set_ylabel('Number of autos')
# Out:
# Text(0, 0.5, 'Number of autos')

# %% [markdown]
# Histograms

# %%
fig = plt.figure(figsize = (10, 6))
ax = fig.gca()
auto_prices['engine-size'].plot.hist(ax = ax)
ax.set_title('Histogram of engine sizes')
ax.set_xlabel('Size (cubic inches)')
ax.set_ylabel('Number of vehicles')
# Out:
# Text(0, 0.5, 'Number of vehicles')

# %%
fig = plt.figure(figsize = (10, 6))
ax = fig.gca()
auto_prices['engine-size'].plot.hist(ax = ax)
ax.set_title('Histogram of engine sizes')
ax.set_xlabel('Size')
ax.set_ylabel('Number of vehicles')
# Out:
# Text(0, 0.5, 'Number of vehicles')

# %%
fig = plt.figure(figsize = (6, 6))
ax = fig.gca()
auto_prices[['engine-size', 'fuel-type']].boxplot(by = 'fuel-type', ax = ax)
ax.set_title('Box plots of auto engine by fuel type')
ax.set_xlabel('Fuel type')
ax.set_ylabel('Engine size')
# Out:
# Text(0, 0.5, 'Engine size')

# %%
fig = plt.figure(figsize = (20, 6))
ax = fig.gca()
auto_prices[['city-mpg', 'make']].boxplot(by = 'make', ax = ax)
ax.set_title('Box plots of auto engine by fuel type')
ax.set_xlabel('Make of vehicle')
ax.set_ylabel('Fuel efficiency (MPG)')
# Out:
# Text(0, 0.5, 'Fuel efficiency (MPG)')

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns
sns.set_style('whitegrid')
sns.kdeplot(auto_prices['engine-size'])
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='Density'>

# %%
import seaborn as sns
sns.set_style('whitegrid')
sns.kdeplot(auto_prices['engine-size'])
ax.set_title('KDE plot of auto engine size')
ax.set_xlabel('Engine size (cubic inches)')
ax.set_ylabel('Density')
# Out:
# Text(17.199999999999996, 0.5, 'Density')

# %%
fig = plt.figure(figsize = (10, 10))
ax = fig.gca()
sns.set_style('whitegrid')
sns.kdeplot(x = auto_prices['engine-size'], y = auto_prices['price'], ax = ax, cmap = "Blues_d")
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %%
fig = plt.figure(figsize = (10, 10))
ax = fig.gca()
sns.set_style('whitegrid')
sns.kdeplot(x = 'city-mpg', y = 'price', data = auto_prices, ax = ax, cmap = "Blues_d")
# Out:
# <AxesSubplot:xlabel='city-mpg', ylabel='price'>

# %% [markdown]
# Colour

# %%
sns.lmplot(x = 'city-mpg', y = 'price',
          data = auto_prices,
          hue = 'fuel-type', 
          palette = 'Set1')

# %%
sns.lmplot(x = 'city-mpg', y = 'price',
          data = auto_prices,
          hue = 'fuel-type', 
          palette = 'Set1', 
          fit_reg = False)

# %%
def auto_color(df, plot_cols):
    import matplotlib.pyplot as plt
    import matplotlib.patches as mpatches
    for col in plot_cols:
        fig = plt.figure(figsize = (10, 10))
        ax = fig.gca()
        temp1 = df.loc[df['fuel-type'] == 'gas'] 
        temp2 = df.loc[df['fuel-type'] == 'diesel']
        if temp1.shape[0] > 0:
            temp1.plot(kind = 'scatter', x = col, y = 'price', ax = ax, color = 'DarkBlue')
        if temp2.shape[0] > 0:
            temp2.plot(kind = 'scatter', x = col, y = 'price', ax = ax, color = 'Red')
    ax.set_title('Scatter plot of price vs. ' + col)
    red_patch = mpatches.Patch(color = 'Red', label = 'Diesel')
    blue_patch = mpatches.Patch(color = 'DarkBlue', label = 'Gas')
    plt.legend(handles = [red_patch, blue_patch])
    return 'Done'

auto_color(auto_prices, ['city-mpg'])
# Out:
# 'Done'

# %%
def auto_size(df, plot_cols):
    import matplotlib.pyplot as plt
    import matplotlib.patches as mpatches
    for col in plot_cols:
        fig = plt.figure(figsize = (6, 6))
        ax = fig.gca()
        temp1 = df.loc[df['fuel-type'] == 'gas'] 
        temp2 = df.loc[df['fuel-type'] == 'diesel']
        if temp1.shape[0] > 0:
            sns.scatterplot(x = col, y = 'price', size = 'engine-size', ax = ax, color = 'DarkBlue', data = temp1, alpha = 0.3)
        if temp2.shape[0] > 0:
            sns.scatterplot(x = col, y = 'price', size = 'engine-size', ax = ax, color = 'Red', data = temp2, alpha = 0.3)
    ax.set_title('Scatter plot of price vs. ' + col)
    red_patch = mpatches.Patch(color = 'Red', label = 'Diesel')
    blue_patch = mpatches.Patch(color = 'DarkBlue', label = 'Gas')
    plt.legend(handles = [red_patch, blue_patch])
    return 'Done'

auto_size(auto_prices, ['city-mpg'])
# Out:
# 'Done'

# %%
auto_prices.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
def auto_size(df, plot_cols):
    import matplotlib.pyplot as plt
    import matplotlib.patches as mpatches
    for col in plot_cols:
        fig = plt.figure(figsize = (6, 6))
        ax = fig.gca()
        temp1 = df.loc[df['fuel-type'] == 'gas'] 
        temp2 = df.loc[df['fuel-type'] == 'diesel']
        if temp1.shape[0] > 0:
            sns.scatterplot(x = col, y = 'price', size = 'engine-size', ax = ax, color = 'DarkBlue', style = 'aspiration', data = temp1, alpha = 0.3)
        if temp2.shape[0] > 0:
            sns.scatterplot(x = col, y = 'price', size = 'engine-size', ax = ax, color = 'Red', style = 'aspiration', data = temp2, alpha = 0.3)
    ax.set_title('Scatter plot of price vs. ' + col)
    red_patch = mpatches.Patch(color = 'Red', label = 'Diesel')
    blue_patch = mpatches.Patch(color = 'DarkBlue', label = 'Gas')
    plt.legend(handles = [red_patch, blue_patch])
    return 'Done'

auto_size(auto_prices, ['city-mpg'])
# Out:
# 'Done'

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 6))
auto_prices['engine-size'].plot.hist(ax = ax[0], bins = 10)
ax[0].set_title('Histogram of auto engine size with 10 bins')
ax[0].set_xlabel('Engine size (cubic inches)')
ax[0].set_ylabel('Number of vehicles')
auto_prices['engine-size'].plot.hist(ax = ax[1], bins = 40)
ax[1].set_title('Histogram of auto engine size with 40 bins')
ax[1].set_xlabel('Engine size (cubic inches)')
ax[1].set_ylabel('Number of vehicles')
# Out:
# Text(0, 0.5, 'Number of vehicles')

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.violinplot(data = auto_prices, x = 'fuel-type', y = 'price', hue = 'aspiration', split = True)
# Out:
# <AxesSubplot:xlabel='fuel-type', ylabel='price'>

# %%
sns.set_style('whitegrid')
sns.boxplot(data = auto_prices, x = 'fuel-type', y = 'price', hue = 'body-style')
# Out:
# <AxesSubplot:xlabel='fuel-type', ylabel='price'>

# %%
sns.violinplot(data = auto_prices, x = 'drive-wheels', y = 'price', hue = 'fuel-type', split = True)
# Out:
# <AxesSubplot:xlabel='drive-wheels', ylabel='price'>

# %%
sns.jointplot(x = 'engine-size', y = 'price', data = auto_prices, alpha = 0.3)

# %%
num_cols = ['length', 'curb-weight', 'engine-size', 'horsepower', 'city-mpg', 'price', 'fuel-type']
sns.pairplot(auto_prices[num_cols], hue = 'fuel-type', palette = 'Set3', diag_kind = 'kde', height = 2)

# %%
num_cols = ['length', 'curb-weight', 'engine-size', 'horsepower', 'city-mpg', 'price', 'fuel-type']
sns.pairplot(auto_prices[num_cols], hue = 'fuel-type', palette = 'Set1', diag_kind = 'kde', height = 2).map_upper(sns.kdeplot)

# %%
def plot_multi(df, col, xcol, ycol):
    fig, ax = plt.subplots(2, 2, figsize = (12, 12))
    xcols = df[xcol].unique()
    ycols = df[ycol].unique()
    for i, xcl in enumerate(xcols):
        for j, ycl in enumerate(ycols):
            auto_prices.loc[(df[xcol] == xcl) & (df[ycol] == ycl), col].plot.hist(ax = ax[i, j], bins = 30)
            ax[i, j].set_title('Histogram of ' + col + ' with ' + xcol + ' = ' + xcl + '\n and ' + ycol + ' = ' + ycl)
            ax[i, j].set_xlabel(col)
plot_multi(auto_prices, 'price', 'aspiration', 'fuel-type')

# %%
g = sns.FacetGrid(auto_prices, col = 'drive-wheels')
g.map(sns.regplot, 'engine-size', 'price', fit_reg = False)

# %%
sns.set(rc={'figure.figsize':(20,20)})
g = sns.FacetGrid(auto_prices, col = 'drive-wheels', row = 'body-style')
g.map(sns.regplot, 'engine-size', 'price', fit_reg = False)

# %%
g = sns.FacetGrid(auto_prices, col = 'drive-wheels',
                 row = 'body-style', hue = 'fuel-type',
                 palette = 'Set1')
g.map(sns.regplot, 'city-mpg', 'price')
